# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori

# %%
df = pd.read_csv('C:/Users/sachin/Desktop/Data analytics/clean2.xls')
df.head()
# Out:
#    X  LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0  1    20000.0  Female  University  Married   24      2      2     -1     -1
# 1  2   120000.0  Female  University   Single   26     -1      2      0      0
# 2  3    90000.0  Female  University   Single   34      0      0      0      0
# 3  4    50000.0  Female  University  Married   37      0      0      0      0
# 4  5    50000.0    Male  University  Married   57     -1      0     -1      0
#
#        ...       BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0      ...             0.0       0.0     689.0       0.0       0.0       0.0
# 1      ...          3261.0       0.0    1000.0    1000.0    1000.0       0.0
# 2      ...         15549.0    1518.0    1500.0    1000.0    1000.0    1000.0
# 3      ...         29547.0    2000.0    2019.0    1200.0    1100.0    1069.0
# 4      ...         19131.0    2000.0   36681.0   10000.0    9000.0     689.0
#
# ...

# %%
df = df[["SEX","EDUCATION","MARRIAGE","default.payment.next.month"]]
df.shape
# Out:
# (30000, 4)

# %%
records = []  
for i in range(0,30000):  
    records.append([str(df.values[i,j]) for j in range(0, 4)])

# %%
records
# Out:
# [['Female', 'University', 'Married', 'Yes'],
#  ['Female', 'University', 'Single', 'Yes'],
#  ['Female', 'University', 'Single', 'No'],
#  ['Female', 'University', 'Married', 'No'],
#  ['Male', 'University', 'Married', 'No'],
#  ['Male', 'Graduate School', 'Single', 'No'],
#  ['Male', 'Graduate School', 'Single', 'No'],
#  ['Female', 'University', 'Single', 'No'],
#  ['Female', 'High School', 'Married', 'No'],
#  ['Male', 'High School', 'Single', 'No'],
#  ['Female', 'High School', 'Single', 'No'],
#  ['Female', 'Graduate School', 'Single', 'No'],
#  ['Female', 'University', 'Single', 'No'],
#  ['Male', 'University', 'Single', 'Yes'],
#  ['Male', 'Graduate School', 'Single', 'No'],
#  ['Female', 'High School', 'Other', 'No'],
#  ['Male', 'Graduate School', 'Single', 'Yes'],
#  ['Male', 'Graduate School', 'Married', 'No'],
#  ['Female', 'Graduate School', 'Married', 'No'],
#  ['Female', 'Graduate School', 'Single', 'No'],
#  ['Female', 'High School', 'Single', 'No'],
# ...

# %%
association_rules = apriori(df, min_support=0.0005, min_confidence=0.01, min_lift=2, min_length=2)  
association_results = list(association_rules)
association_results
# Out:
# []

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print('Rules : ', items)
    #print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rules :  ['nan', 'High School']
# Support: 0.0014666666666666667
# Confidence: 0.6470588235294117
# Lift: 3.9478878799842083
# ...
# Rules :  ['Other', 'High School', 'Female']
# Support: 0.0022333333333333333
# Confidence: 0.022890331397335154
# Lift: 2.126036971888714
# ...
# Rules :  ['nan', 'High School', 'Female']
# Support: 0.0010666666666666667
# Confidence: 0.010932695592757091
# Lift: 4.823248055628128
# ...
# Rules :  ['nan', 'High School', 'No']
# Support: 0.0013333333333333333
# Confidence: 0.010869565217391304
# Lift: 4.795396419437339
# ...
# Rules :  ['Other', 'High School', 'Yes']
# Support: 0.0009
# Confidence: 0.021827000808407437
# Lift: 2.0272756168799475
# ...
# Rules :  ['Other', 'High School', 'Female', 'No']
# Support: 0.0017
# Confidence: 0.022818791946308724
# Lift: 2.1193924408336273
# ...
# Rules :  ['nan', 'High School', 'Female', 'No']
# Support: 0.001
# Confidence: 0.01342281879194631
# Lift: 5.921831819976313
# ...
# Rules :  ['Other', 'High School', 'Female', 'Yes']
# ...
